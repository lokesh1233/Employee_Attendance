# %%
# !pip install weather-api
# Out:
# Collecting weather-api
#   Downloading https://files.pythonhosted.org/packages/bd/7f/18d323e237efe568aa3201e3d8b2140669c16f50e0a0330d564c9ff79f07/weather_api-1.0.7-py2.py3-none-any.whl
# Collecting colorize (from weather-api)
#   Downloading https://files.pythonhosted.org/packages/e5/c7/f1c41492464bd0626fadd9fd67ac00ac6c5338649ec697296c4fc46edbb5/colorize-1.0.4-py2.py3-none-any.whl
# Requirement already satisfied: requests in c:\users\lokesh\jupyter_works\venv\lib\site-packages (from weather-api) (2.21.0)
# Collecting ptable (from weather-api)
#   Downloading https://files.pythonhosted.org/packages/ab/b3/b54301811173ca94119eb474634f120a49cd370f257d1aae5a4abaf12729/PTable-0.9.2.tar.gz
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\lokesh\jupyter_works\venv\lib\site-packages (from requests->weather-api) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lokesh\jupyter_works\venv\lib\site-packages (from requests->weather-api) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lokesh\jupyter_works\venv\lib\site-packages (from requests->weather-api) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\lokesh\jupyter_works\venv\lib\site-packages (from requests->weather-api) (2.8)
# Building wheels for collected packages: ptable
#   Running setup.py bdist_wheel for ptable: started
#   Running setup.py bdist_wheel for ptable: finished with status 'done'
#   Stored in directory: C:\Users\Lokesh\AppData\Local\pip\Cache\wheels\22\cc\2e\55980bfe86393df3e9896146a01f6802978d09d7ebcba5ea56
# Successfully built ptable
# Installing collected packages: colorize, ptable, weather-api
# Successfully installed colorize-1.0.4 ptable-0.9.2 weather-api-1.0.7

# %%
from weather import Weather, Unit

weather = Weather(unit=Unit.CELSIUS)

lookup = weather.lookup(560743)
condition = lookup.condition

print(condition.text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# c:\users\lokesh\jupyter_works\venv\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# c:\users\lokesh\jupyter_works\venv\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# c:\users\lokesh\jupyter_works\venv\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# c:\users\lokesh\jupyter_works\venv\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# c:\users\lokesh\jupyter_works\venv\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\users\lokesh\jupyter_works\venv\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000286DC969208>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='query.yahooapis.com', port=80): Max retries exceeded with url: /v1/public/yql?q=select%20*%20from%20weather.forecast%20where%20woeid%20=%20'560743'%20and%20u='c'%20&format=json (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000286DC969208>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-edf131a0a1cc> in <module>
#       3 weather = Weather(unit=Unit.CELSIUS)
#       4
# ----> 5 lookup = weather.lookup(560743)
#       6 condition = lookup.condition
#       7
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\weather\weather.py in lookup(self, woeid)
#      18         url = "%s?q=select * from weather.forecast where woeid = '%s' and u='%s' &format=json" % (
#      19             self.URL, woeid, self.unit)
# ---> 20         results = self._call(url)
#      21         return results
#      22
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\weather\weather.py in _call(self, url)
#      36
#      37     def _call(self, url):
# ---> 38         req = requests.get(url)
#      39         if self.log:
#      40             self.logger.info("Request URL: %s" % req.url)
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\users\lokesh\jupyter_works\venv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='query.yahooapis.com', port=80): Max retries exceeded with url: /v1/public/yql?q=select%20*%20from%20weather.forecast%20where%20woeid%20=%20'560743'%20and%20u='c'%20&format=json (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000286DC969208>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
