# %%
import pandas as pd

#prophet model
from fbprophet import Prophet

# load the data from google drive
from google.colab import drive

# this will prompt for authorization
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
#  20150329_231009.jpg		      FOS.apk
#  AttendaenceProcess.csv		      FOSQUALITY.apk
# 'Backend OData in Json format.gdoc'   getting_started_with_apache_spark.pdf
# 'Backend OData in Json format.txt'   'hareesh reddy (1) (1).gdoc'
# 'churn-master (1).zip'		      img055.jpg
#  churn-master.zip		      Math662TB-09S.pdf
# 'Churn prediction.pptx'		     'Monthly budget (1).gsheet'
#  cloudera-spark.pdf		     'Monthly budget.gsheet'
# 'Colab Notebooks'		     'Print - Application.pdf'
# 'Copy of AttendaenceProcess.csv'     'Room Expenses sheet.gsheet'
# 'e-P A S S.pdf'			     'sales analyses.gsheet'
#  export_1_20180610.zip		     'Team Members Tasks.gsheet'

# %%
data = pd.read_csv("/content/drive/My Drive/AttendaenceProcess.csv")
data.columns = ["ds", "y"]

# %%
data['Date'] = data.Date.astype("datetime64[ns]")

# %%
data.set_index("Date", inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 2 columns):
# Date          92 non-null object
# Attendance    92 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ KB

# %%
# Python
m = Prophet()
m.fit(data)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 452 2019-12-27
# 453 2019-12-28
# 454 2019-12-29
# 455 2019-12-30
# 456 2019-12-31

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 452 2019-12-27   95.916672   77.175123  114.126938
# 453 2019-12-28   72.071627   53.617650   92.003905
# 454 2019-12-29   61.959056   43.124964   81.902935
# 455 2019-12-30  100.118661   82.176930  119.220778
# 456 2019-12-31   95.113765   76.407020  114.227176

# %%
# Python
fig1 = m.plot(forecast)

# %%
# Python
fig2 = m.plot_components(forecast)
